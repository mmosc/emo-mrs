# %%
import pandas as pd
import polars as pl
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
import json
import numpy as np
import pickle
from datetime import datetime
from scipy.stats import spearmanr,pearsonr,kendalltau,pointbiserialr
DATA_ROOT = '/media/gustavo/Storage/Datasets/Onion20k'
DATA_ROOT_URL=Path(DATA_ROOT)
sns.set_theme()
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
full_feat_tracks=pd.read_csv(DATA_ROOT_URL/'v3_emotions_familiarity_full_feat_stack.tsv',sep='\t')

# %%
full_feat_tracks.describe()
# Out:
#                score         lfm_id
# count  244352.000000  244352.000000
# mean        6.334238   12229.643318
# std        15.731860    7035.309843
# min         0.001056       0.000000
# 25%         0.062016    6132.000000
# 50%         1.000000   12234.000000
# 75%         6.000000   18304.250000
# max       400.000000   24407.000000

# %%
full_feat_tracks['gem_label'].value_counts()
# Out:
# r_transcendence            11316
# avg_transcendence          11316
# nr_transcendence           11316
# r_all_transcendence        11316
# r_joyful activation         9323
# avg_joyful activation       9323
# r_all_joyful activation     9323
# nr_joyful activation        9323
# nr_nostalgia                8458
# avg_nostalgia               8458
# r_nostalgia                 8458
# r_all_nostalgia             8458
# r_power                     7798
# avg_power                   7798
# r_all_power                 7798
# nr_power                    7798
# r_wonder                    7668
# nr_wonder                   7668
# r_all_wonder                7668
# avg_wonder                  7668
# avg_peacefulness            6351
# r_all_peacefulness          6351
# nr_peacefulness             6351
# r_peacefulness              6351
# avg_sadness                 6121
# r_sadness                   6121
# r_all_sadness               6121
# nr_sadness                  6121
# r_all_tension               2455
# r_tension                   2455
# avg_tension                 2455
# nr_tension                  2455
# avg_tenderness              1598
# nr_tenderness               1598
# r_all_tenderness            1598
# r_tenderness                1598
# Name: gem_label, dtype: int64

# %%
gems_groups = full_feat_tracks.groupby('gem_label')['lfm_id'].apply(lambda x: list(x))
gems_to_lfm_tracks= gems_groups.to_dict()

# %%
def calculate_bll_score_global(data, decay=0.5):
    return (
        data.with_column(
            (pl.col("timestamp").max().dt.offset_by("1h").alias("ts_ref")).over(
                pl.col(["user_id"])
            )
        )
        .with_column(
            (pl.col("ts_ref") - pl.col("timestamp")).dt.timestamp().alias("ts_diff")
        )
        .filter(pl.col("ts_diff") > 0)
        .groupby(["track_id", "user_id"])
        .agg([pl.col("ts_diff").pow(-decay).sum().log().alias("bll_score")])
        .groupby("track_id")
        .agg(pl.col("bll_score").mean())
    )


def calculate_bll_score(data, offset="2w1h", decay=0.5):
    return (
        data.with_column(
            (pl.col("timestamp").min().dt.offset_by(offset).alias("ts_ref")).over(
                pl.col(["track_id", "user_id"])
            )
        )
        .with_column(
            (pl.col("ts_ref") - pl.col("timestamp")).dt.timestamp().alias("ts_diff")
        )
        .filter(pl.col("ts_diff") > 0)
        .groupby(["track_id", "user_id"])
        .agg([(pl.col("ts_diff").pow(-decay).sum()).log().alias("bll_score")])
        .groupby("track_id")
        .agg(pl.col("bll_score").mean())
    )


def calculate_bll_score_min_freq(data, offset="2w1h", decay=0.5, R=3):
    return (
        data.with_column(
            (pl.col("timestamp").min().dt.offset_by(offset).alias("ts_ref")).over(
                pl.col(["track_id", "user_id"])
            )
        )
        .with_column(
            (pl.col("ts_ref") - pl.col("timestamp")).dt.timestamp().alias("ts_diff")
        )
        .filter((pl.col("ts_diff") > 0))
        .groupby(["track_id", "user_id"])
        .agg(
            [
                (pl.col("ts_diff").pow(-decay).sum()).log().alias("bll_score"),
                pl.col("ts_diff").count().alias("count"),
            ]
        )
        .filter(pl.col("count") >= R)
        .groupby("track_id")
        .agg(pl.col("bll_score").mean())
    )

# %%
def calculate_bll_score_global(data, decay=0.5):
    return (
        data.with_column((pl.col("timestamp").max().dt.offset_by('1h').alias("ts_ref")).over(
        pl.col([ "user_id"])
    )).with_column((pl.col("ts_ref") - pl.col("timestamp")).dt.timestamp().alias("ts_diff")
).filter(pl.col("ts_diff")>0).groupby(['track_id','user_id']).agg([pl.col('ts_diff').pow(-decay).sum().log().alias("bll_score")]).groupby('track_id').agg(pl.col("bll_score").mean()))

def calculate_bll_score(data, offset="2w1h",decay=0.5):
    return (
        data.with_column((pl.col("timestamp").min().dt.offset_by(offset).alias("ts_ref")).over(
        pl.col(["track_id", "user_id"])
    )).with_column((pl.col("ts_ref") - pl.col("timestamp")).dt.timestamp().alias("ts_diff")
).filter(pl.col("ts_diff")>0).groupby(['track_id','user_id']).agg([(pl.col('ts_diff').pow(-decay).sum()).log().alias("bll_score")]).groupby('track_id').agg(pl.col("bll_score").mean()))

def calculate_bll_score_min_freq(data, offset="2w1h",decay=0.5,R=3):
    return (
        data.with_column((pl.col("timestamp").min().dt.offset_by(offset).alias("ts_ref")).over(
        pl.col(["track_id", "user_id"])
    )).with_column((pl.col("ts_ref") - pl.col("timestamp")).dt.timestamp().alias("ts_diff")
).filter((pl.col("ts_diff")>0)).groupby(['track_id','user_id']).agg([(pl.col('ts_diff').pow(-decay).sum()).log().alias("bll_score"),pl.col('ts_diff').count().alias('count')]).filter(pl.col('count')>=R).groupby('track_id').agg(pl.col("bll_score").mean()))

# %% [markdown]
# # Calculating popularity measures

# %%
data = pl.scan_csv(DATA_ROOT_URL/'user_item_timestamp.tsv',sep='\t').rename(mapping={"track_index":"track_id","time":"timestamp"})

# %%
# !wc -l {DATA_ROOT_URL}/user_item_timestamp.tsv
# Out:
# 230884331 /media/gustavo/Storage/Datasets/Onion20k/user_item_timestamp.tsv

# %%
data.select([pl.col('user_id').n_unique().alias("unique_users"),pl.col('track_id').n_unique().alias("unique_tracks")]).collect()
# Out:
# shape: (1, 2)
# ┌──────────────┬───────────────┐
# │ unique_users ┆ unique_tracks │
# │ ---          ┆ ---           │
# │ u32          ┆ u32           │
# ╞══════════════╪═══════════════╡
# │ 118934       ┆ 24402         │
# └──────────────┴───────────────┘

# %%
data.filter(pl.col('track_id').is_in(pl.lit(merged_data['lfm_id'].unique()))).select(pl.col('user_id').n_unique()).collect()
# Out:
# shape: (1, 1)
# ┌─────────┐
# │ user_id │
# │ ---     │
# │ u32     │
# ╞═════════╡
# │ 118289  │
# └─────────┘

# %%
itempop_all=calculate_pop(data)

# %%
itempop_all.write_csv(DATA_ROOT_URL/'track_all_popularity.csv')

# %%
itemfam_all = calculate_familiarity(data,R=20)

# %%
itemfam_all.write_csv(DATA_ROOT_URL/'track_all_familiarity.csv')

# %%
itemfam5_all = calculate_familiarity(data,R=5)
itemfam5_all.write_csv(DATA_ROOT_URL/'track_all_familiarity5.csv')

# %%
offset="1mo"
decay=0.5
min_freq=3
data = pl.scan_csv(DATA_ROOT_URL/'user_item_timestamp.tsv',sep='\t',parse_dates=True).rename(mapping={"track_index":"track_id","time":"timestamp"})
data.pipe(calculate_bll_score,offset=offset,decay=decay).collect().write_csv(DATA_ROOT_URL/f"bll_scores_{offset}.csv")
data.pipe(calculate_bll_score_min_freq,offset=offset,decay=decay,R=min_freq).collect().write_csv(DATA_ROOT_URL/f"bll_scores_minfreq_{offset}.csv")
#data.pipe(calculate_bll_score_global,decay=decay).collect().write_csv(DATA_ROOT_URL/f"bll_scores_global.csv")

# %%
offset="1h"
decay=0.5
min_freq=3
data = pl.scan_csv(DATA_ROOT_URL/'user_item_timestamp.tsv',sep='\t',parse_dates=True).rename(mapping={"track_index":"track_id","time":"timestamp"})
bll_item_scores= data.with_column((pl.col("timestamp").max().dt.offset_by(offset).alias("ts_ref")).over(
        pl.col([ "user_id"])
    )).with_column((pl.col("ts_ref") - pl.col("timestamp")).dt.timestamp().alias("ts_diff")
).filter(pl.col("ts_diff")>0).groupby(['track_id','user_id']).agg([pl.col('ts_diff').pow(-decay).sum().alias("bll_score")]).sort('user_id').collect()
bll_item_scores.write_csv(DATA_ROOT_URL/'bll_test.csv')

# %%
from scipy.stats import beta

sigmoid = lambda x: 1/(1 + np.exp(-x))
x_norm = lambda x : (x-np.min(x))/(np.max(x)-np.min(x))
normalized = bll_item_scores[bll_item_scores['track_id']==808]['bll_score'].to_numpy()
pars =beta.fit(normalized)
sns.histplot(normalized)
# Out:
# /home/gustavo/anaconda3/envs/recbole/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py:639: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# /home/gustavo/anaconda3/envs/recbole/lib/python3.8/site-packages/scipy/optimize/minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# <AxesSubplot:ylabel='Count'>

# %%
itembll_all= pd.read_csv(DATA_ROOT_URL/'bll_scores_1mo.csv')
itembll_minfreq_all= pd.read_csv(DATA_ROOT_URL/'bll_scores_minfreq_1mo.csv')
data_m=itembll_all.merge(itembll_minfreq_all,on='track_id',suffixes=["","_minfreq"],how='inner')[['bll_score','bll_score_minfreq']]
print(spearmanr(data_m))
# Out:
# SpearmanrResult(correlation=0.47359656005243234, pvalue=0.0)

# %%
sns.regplot(data=data_m,x='bll_score',y='bll_score_minfreq')
# Out:
# <AxesSubplot:xlabel='bll_score', ylabel='bll_score_minfreq'>

# %%
itembll_all= pd.read_csv(DATA_ROOT_URL/'bll_scores_1mo.csv')
itembll_minfreq_all= pd.read_csv(DATA_ROOT_URL/'bll_scores_minfreq_1mo.csv')
data_m=itembll_all.merge(itembll_minfreq_all,on='track_id',suffixes=["","_minfreq"],how='inner')[['bll_score','bll_score_minfreq']]
print(spearmanr(data_m))
sns.regplot(data=data_m,x='bll_score',y='bll_score_minfreq',)
# Out:
# SpearmanrResult(correlation=0.7415891470140522, pvalue=0.0)
# <AxesSubplot:xlabel='bll_score', ylabel='bll_score_minfreq'>

# %%
itembll_all= pd.read_csv(DATA_ROOT_URL/'bll_scores_1w.csv')
itembll_minfreq_all= pd.read_csv(DATA_ROOT_URL/'bll_scores_minfreq_1w.csv')
data_m=itembll_all.merge(itembll_minfreq_all,on='track_id',suffixes=["","_minfreq"],how='inner')[['bll_score','bll_score_minfreq']]
print(spearmanr(data_m))
sns.regplot(data=data_m,x='bll_score',y='bll_score_minfreq',lo)
# Out:
# SpearmanrResult(correlation=0.6243740867828497, pvalue=0.0)
# <AxesSubplot:xlabel='bll_score', ylabel='bll_score_minfreq'>

# %% [markdown]
# # Calculating correlations (Onion/EMMA)

# %% [markdown]
# 1. **Global popularity** : Relative proportion of unique listeners per track
# 2. **Global familiarity** : Relative proportion of users that played the track at least R>=3 and all unique listeners of that same track
# 3. **Average user BLL score in Timeframe**: Calculate BLL for each (user,track) pair in the timewindow='6mo' after the first appearance of the (user,track) listening event. Then group (user,track,bll_score) by track assigning the mean of the bll_scores of the group

# %%
itempop_all= pd.read_csv(DATA_ROOT_URL/'track_all_popularity.csv')
itemfam_all= pd.read_csv(DATA_ROOT_URL/'track_all_familiarity.csv')
itemfam5_all= pd.read_csv(DATA_ROOT_URL/'track_all_familiarity5.csv')
itembll_all= pd.read_csv(DATA_ROOT_URL/'bll_scores_global.csv')
t_itembll_all= pd.read_csv(DATA_ROOT_URL/'bll_scores_1mo.csv')
merged_data = full_feat_tracks.merge(itempop_all,left_on='lfm_id',right_on='track_id',how='inner')
merged_data = merged_data.merge(itemfam_all,left_on='lfm_id',right_on='track_id',how='inner',suffixes=["","_3"])
merged_data = merged_data.merge(itembll_all,left_on='lfm_id',right_on='track_id',how='left',suffixes=["","_3"])
merged_data = merged_data.merge(t_itembll_all,left_on='lfm_id',right_on='track_id',how='left',suffixes=["","_t"])
merged_data.loc[merged_data['bll_score'].isna(),'bll_score']=0.0
merged_data.loc[merged_data['bll_score_t'].isna(),'bll_score_t']=0.0
gems_groups = merged_data.groupby('gem_label')

# %%
merged_data.drop_duplicates("lfm_id")['track_playcount'].quantile(0.999)
# Out:
# 144176.64200000468

# %%
sns.set_context(sns.plotting_context('talk'))
sns.histplot(merged_data['gem_label'])
plt.xticks(rotation=90)
plt.title(f"Unique tracks:{merged_data['lfm_id'].nunique()}")
plt.show()

# %% [markdown]
# ## Calculating correlations on groups of Tracks (Onion/EMMA)

# %%
from collections import defaultdict
corr_all= defaultdict(lambda :list())
cols=['bll_score','bll_score_t','pop_i','fam_i']
metrics = spearmanr,#pearsonr,kendalltau,pointbiserialr
for label,tracks in gems_groups:
    #print([len(tracks),tracks['lfm_id'].nunique(),(tracks['score']>0).sum()])
    corr_all['label'].append(label)
    corr_all[f'|label|'].append(tracks['score'].count())
    for col in cols:
        for metric in metrics:
            corr_val,pval = metric(tracks['score'],tracks[col])
            corr_all[f'{col}_{metric.__name__}'].append(corr_val)

# %%
corr_df= pd.DataFrame(corr_all)
corr_df.set_index('label',inplace=True)
with sns.plotting_context('notebook'):
    plt.figure(figsize=(7,10))
    sns.heatmap(corr_df.iloc[:,1:], annot=True,cmap='Blues')

# %%
sns.set_context(sns.plotting_context('paper'))
g = sns.FacetGrid(merged_data.sort_values('gem_label'),col='gem_label',col_wrap=5 ,sharey=False,sharex=False)
g = g.map(sns.histplot, 'score',kde=True)

# %%
g = sns.FacetGrid(merged_data,col='gem_label',col_wrap=3 ,sharey=False,sharex=False)
g = g.map(sns.histplot, 'pop_i',kde=True)

# %%
g = sns.FacetGrid(merged_data,col='gem_label',col_wrap=3 ,sharey=False,sharex=False)
g = g.map(sns.histplot, 'fam_i',kde=True)

# %%
g = sns.FacetGrid(merged_data,col='gem_label',col_wrap=3,sharex=False,sharey=False )
g = g.map(sns.histplot, 'bll_score',kde=True)

# %% [markdown]
# ## Calculation of correlation bewtween EMMA labels with audio features (Onion/EMMA)

# %%
audio_features= pd.read_csv(DATA_ROOT_URL/'emotion_audiofeatures.csv')
lfm_listening_counts= pd.read_csv(DATA_ROOT_URL/'lfm_listening_counts.csv',skiprows=1,names=['lfm_id','listening_count'])
merged_data = full_feat_tracks.merge(audio_features,left_on='lfm_id',right_on='lfm_id',how='inner').dropna(subset='valence')
itempop_all= pd.read_csv(DATA_ROOT_URL/'track_all_popularity.csv')
itemfam_all= pd.read_csv(DATA_ROOT_URL/'track_all_familiarity.csv')
merged_data = merged_data.merge(itempop_all,left_on='lfm_id',right_on='track_id',how='inner')
merged_data = merged_data.merge(itemfam_all,left_on='lfm_id',right_on='track_id',how='inner',suffixes=["","_3"])
merged_data = merged_data.merge(lfm_listening_counts,left_on='lfm_id',right_on='lfm_id',how='inner',suffixes=["","_3"])
gems_groups = merged_data.groupby('gem_label')
from collections import defaultdict
corr_all= defaultdict(lambda :list())
cols=[ 'valence', 'pop_i','fam_i','listening_count']
cols =['danceability', 'energy', 'key', 'loudness',
       'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'duration_ms', 'time_signature']
for label,tracks in gems_groups:
    #print([len(tracks),tracks['lfm_id'].nunique(),(tracks['score']>0).sum()])
    corr_all['label'].append(label)
    for col in cols:
        corr_val,pval = spearmanr(tracks[['score',col]])
        corr_all[f'{col}'].append(corr_val)

# %%
audio_features.columns
# Out:
# Index(['Unnamed: 0', 'lfm_id', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
corr_df= pd.DataFrame(corr_all)
#corr_df.set_index('group',inplace=True)
cm = sns.color_palette("Blues", as_cmap=True)
s=corr_df.style.background_gradient(cmap=cm,subset=corr_df.columns[2:]).hide(axis='index')
print(s.to_latex(
    hrules=True,
    clines='skip-last;index',
   caption='table',
    position_float='centering',
    multicol_align='l',
    convert_css=True,
    ))
# Out:
# \begin{table}
# \centering
# \caption{table}
# \begin{tabular}{lrrrrr}
# \toprule
# label & |label| & bll_score_spearmanr & bll_score_t_spearmanr & pop_i_spearmanr & fam_i_spearmanr \\
# \midrule
# joyful activation & 6048 & {\cellcolor[HTML]{083877}} \color[HTML]{F1F1F1} 0.075245 & {\cellcolor[HTML]{084285}} \color[HTML]{F1F1F1} 0.128098 & {\cellcolor[HTML]{BCD7EB}} \color[HTML]{000000} -0.318430 & {\cellcolor[HTML]{81BADB}} \color[HTML]{000000} -0.275565 \\
# nostalgia & 5500 & {\cellcolor[HTML]{5CA4D0}} \color[HTML]{F1F1F1} -0.009590 & {\cellcolor[HTML]{4D99CA}} \color[HTML]{F1F1F1} 0.050950 & {\cellcolor[HTML]{3686C0}} \color[HTML]{F1F1F1} -0.205993 & {\cellcolor[HTML]{083979}} \color[HTML]{F1F1F1} -0.155057 \\
# peacefulness & 4213 & {\cellcolor[HTML]{D0E2F2}} \color[HTML]{000000} -0.079751 & {\cellcolor[HTML]{E4EFF9}} \color[HTML]{000000} -0.060058 & {\cellcolor[HTML]{AACFE5}} \color[HTML]{000000} -0.302366 & {\cellcolor[HTML]{C1D9ED}} \color[HTML]{000000} -0.318322 \\
# power & 5186 & {\cellcolor[HTML]{083471}} \color[HTML]{F1F1F1} 0.078442 & {\cellcolor[HTML]{1865AC}} \color[HTML]{F1F1F1} 0.096591 & {\cellcolor[HTML]{2E7EBC}} \color[HTML]{F1F1F1} -0.197560 & {\cellcolor[HTML]{08306B}} \color[HTML]{F1F1F1} -0.146316 \\
# sadness & 4145 & {\cellcolor[HTML]{08326E}} \color[HTML]{F1F1F1} 0.079992 & {\cellcolor[HTML]{084A91}} \color[HTML]{F1F1F1} 0.120992 & {\cellcolor[HTML]{ABD0E6}} \color[HTML]{000000} -0.304626 & {\cellcolor[HTML]{4191C6}} \color[HTML]{F1F1F1} -0.233491 \\
# tenderness & 1094 & {\cellcolor[HTML]{8ABFDD}} \color[HTML]{000000} -0.033812 & {\cellcolor[HTML]{94C4DF}} \color[HTML]{000000} 0.007809 & {\cellcolor[HTML]{F7FBFF}} \color[HTML]{000000} -0.401435 & {\cellcolor[HTML]{F7FBFF}} \color[HTML]{000000} -0.380841 \\
# tension & 1634 & {\cellcolor[HTML]{F7FBFF}} \color[HTML]{000000} -0.119219 & {\cellcolor[HTML]{F7FBFF}} \color[HTML]{000000} -0.081831 & {\cellcolor[HTML]{3E8EC4}} \color[HTML]{F1F1F1} -0.215145 & {\cellcolor[HTML]{3888C1}} \color[HTML]{F1F1F1} -0.225801 \\
# transcendence & 7533 & {\cellcolor[HTML]{D6E5F4}} \color[HTML]{000000} -0.084750 & {\cellcolor[HTML]{AED1E7}} \color[HTML]{000000} -0.008241 & {\cellcolor[HTML]{08306B}} \color[HTML]{F1F1F1} -0.109878 & {\cellcolor[HTML]{083C7D}} \color[HTML]{F1F1F1} -0.158099 \\
# wonder & 5083 & {\cellcolor[HTML]{08306B}} \color[HTML]{F1F1F1} 0.081859 & {\cellcolor[HTML]{08306B}} \color[HTML]{F1F1F1} 0.143053 & {\cellcolor[HTML]{4896C8}} \color[HTML]{F1F1F1} -0.224417 & {\cellcolor[HTML]{083776}} \color[HTML]{F1F1F1} -0.153118 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
s
# Out:
# <style type="text/css">
# #T_5fc1e_row0_col2 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_5fc1e_row0_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_5fc1e_row0_col4 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_5fc1e_row0_col5 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_5fc1e_row1_col2 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_5fc1e_row1_col3 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_5fc1e_row1_col4 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_5fc1e_row1_col5 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_5fc1e_row2_col2 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_5fc1e_row2_col3 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_5fc1e_row2_col4 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_5fc1e_row2_col5 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_5fc1e_row3_col2 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_5fc1e_row3_col3 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_5fc1e_row3_col4 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_5fc1e_row3_col5, #T_5fc1e_row7_col4, #T_5fc1e_row8_col2, #T_5fc1e_row8_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5fc1e_row4_col2 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_5fc1e_row4_col3 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_5fc1e_row4_col4 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_5fc1e_row4_col5 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_5fc1e_row5_col2 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_5fc1e_row5_col3 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_5fc1e_row5_col4, #T_5fc1e_row5_col5, #T_5fc1e_row6_col2, #T_5fc1e_row6_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5fc1e_row6_col4 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_5fc1e_row6_col5 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_5fc1e_row7_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_5fc1e_row7_col3 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_5fc1e_row7_col5 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_5fc1e_row8_col4 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_5fc1e_row8_col5 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5fc1e">
#   <thead>
#     <tr>
#       <th id="T_5fc1e_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_5fc1e_level0_col1" class="col_heading level0 col1" >|label|</th>
#       <th id="T_5fc1e_level0_col2" class="col_heading level0 col2" >bll_score_spearmanr</th>
#       <th id="T_5fc1e_level0_col3" class="col_heading level0 col3" >bll_score_t_spearmanr</th>
#       <th id="T_5fc1e_level0_col4" class="col_heading level0 col4" >pop_i_spearmanr</th>
#       <th id="T_5fc1e_level0_col5" class="col_heading level0 col5" >fam_i_spearmanr</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5fc1e_row0_col0" class="data row0 col0" >joyful activation</td>
#       <td id="T_5fc1e_row0_col1" class="data row0 col1" >6048</td>
#       <td id="T_5fc1e_row0_col2" class="data row0 col2" >0.075245</td>
#       <td id="T_5fc1e_row0_col3" class="data row0 col3" >0.128098</td>
#       <td id="T_5fc1e_row0_col4" class="data row0 col4" >-0.318430</td>
#       <td id="T_5fc1e_row0_col5" class="data row0 col5" >-0.275565</td>
#     </tr>
#     <tr>
#       <td id="T_5fc1e_row1_col0" class="data row1 col0" >nostalgia</td>
#       <td id="T_5fc1e_row1_col1" class="data row1 col1" >5500</td>
#       <td id="T_5fc1e_row1_col2" class="data row1 col2" >-0.009590</td>
#       <td id="T_5fc1e_row1_col3" class="data row1 col3" >0.050950</td>
#       <td id="T_5fc1e_row1_col4" class="data row1 col4" >-0.205993</td>
#       <td id="T_5fc1e_row1_col5" class="data row1 col5" >-0.155057</td>
#     </tr>
#     <tr>
#       <td id="T_5fc1e_row2_col0" class="data row2 col0" >peacefulness</td>
#       <td id="T_5fc1e_row2_col1" class="data row2 col1" >4213</td>
#       <td id="T_5fc1e_row2_col2" class="data row2 col2" >-0.079751</td>
#       <td id="T_5fc1e_row2_col3" class="data row2 col3" >-0.060058</td>
#       <td id="T_5fc1e_row2_col4" class="data row2 col4" >-0.302366</td>
#       <td id="T_5fc1e_row2_col5" class="data row2 col5" >-0.318322</td>
#     </tr>
#     <tr>
#       <td id="T_5fc1e_row3_col0" class="data row3 col0" >power</td>
#       <td id="T_5fc1e_row3_col1" class="data row3 col1" >5186</td>
#       <td id="T_5fc1e_row3_col2" class="data row3 col2" >0.078442</td>
#       <td id="T_5fc1e_row3_col3" class="data row3 col3" >0.096591</td>
#       <td id="T_5fc1e_row3_col4" class="data row3 col4" >-0.197560</td>
#       <td id="T_5fc1e_row3_col5" class="data row3 col5" >-0.146316</td>
#     </tr>
#     <tr>
#       <td id="T_5fc1e_row4_col0" class="data row4 col0" >sadness</td>
#       <td id="T_5fc1e_row4_col1" class="data row4 col1" >4145</td>
#       <td id="T_5fc1e_row4_col2" class="data row4 col2" >0.079992</td>
#       <td id="T_5fc1e_row4_col3" class="data row4 col3" >0.120992</td>
#       <td id="T_5fc1e_row4_col4" class="data row4 col4" >-0.304626</td>
#       <td id="T_5fc1e_row4_col5" class="data row4 col5" >-0.233491</td>
#     </tr>
#     <tr>
#       <td id="T_5fc1e_row5_col0" class="data row5 col0" >tenderness</td>
#       <td id="T_5fc1e_row5_col1" class="data row5 col1" >1094</td>
#       <td id="T_5fc1e_row5_col2" class="data row5 col2" >-0.033812</td>
#       <td id="T_5fc1e_row5_col3" class="data row5 col3" >0.007809</td>
#       <td id="T_5fc1e_row5_col4" class="data row5 col4" >-0.401435</td>
#       <td id="T_5fc1e_row5_col5" class="data row5 col5" >-0.380841</td>
#     </tr>
#     <tr>
#       <td id="T_5fc1e_row6_col0" class="data row6 col0" >tension</td>
#       <td id="T_5fc1e_row6_col1" class="data row6 col1" >1634</td>
#       <td id="T_5fc1e_row6_col2" class="data row6 col2" >-0.119219</td>
#       <td id="T_5fc1e_row6_col3" class="data row6 col3" >-0.081831</td>
#       <td id="T_5fc1e_row6_col4" class="data row6 col4" >-0.215145</td>
#       <td id="T_5fc1e_row6_col5" class="data row6 col5" >-0.225801</td>
#     </tr>
#     <tr>
#       <td id="T_5fc1e_row7_col0" class="data row7 col0" >transcendence</td>
#       <td id="T_5fc1e_row7_col1" class="data row7 col1" >7533</td>
#       <td id="T_5fc1e_row7_col2" class="data row7 col2" >-0.084750</td>
#       <td id="T_5fc1e_row7_col3" class="data row7 col3" >-0.008241</td>
#       <td id="T_5fc1e_row7_col4" class="data row7 col4" >-0.109878</td>
#       <td id="T_5fc1e_row7_col5" class="data row7 col5" >-0.158099</td>
#     </tr>
#     <tr>
#       <td id="T_5fc1e_row8_col0" class="data row8 col0" >wonder</td>
#       <td id="T_5fc1e_row8_col1" class="data row8 col1" >5083</td>
#       <td id="T_5fc1e_row8_col2" class="data row8 col2" >0.081859</td>
#       <td id="T_5fc1e_row8_col3" class="data row8 col3" >0.143053</td>
#       <td id="T_5fc1e_row8_col4" class="data row8 col4" >-0.224417</td>
#       <td id="T_5fc1e_row8_col5" class="data row8 col5" >-0.153118</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Calculating correlations on binarized EMMA labels (Onion/EMMA)

# %%
audio_features= pd.read_csv(DATA_ROOT_URL/'emotion_audiofeatures.csv')
lfm_listening_counts= pd.read_csv(DATA_ROOT_URL/'lfm_listening_counts.csv',skiprows=1,names=['lfm_id','listening_count'])
merged_data = full_feat_tracks.merge(audio_features,left_on='lfm_id',right_on='lfm_id',how='inner').dropna(subset='valence')
itempop_all= pd.read_csv(DATA_ROOT_URL/'track_all_popularity.csv')
itemfam_all= pd.read_csv(DATA_ROOT_URL/'track_all_familiarity.csv')
merged_data = merged_data.merge(itempop_all,left_on='lfm_id',right_on='track_id',how='inner')
merged_data = merged_data.merge(itemfam_all,left_on='lfm_id',right_on='track_id',how='inner',suffixes=["","_3"])
merged_data = merged_data.merge(lfm_listening_counts,left_on='lfm_id',right_on='lfm_id',how='inner',suffixes=["","_3"])
gems_groups = merged_data.groupby('gem_label')

# %%
sns.set_context(sns.plotting_context('talk'))
sns.histplot(merged_data['gem_label'])
plt.xticks(rotation=90)
plt.title(f"Unique tracks:{merged_data['lfm_id'].nunique()}")
plt.show()

# %%
merged_data = merged_data.drop_duplicates(['lfm_id']).merge(merged_data.pivot(columns='gem_label', index='lfm_id', values='score'), left_on='lfm_id',right_index=True,how='inner')

# %%
from collections import defaultdict
corr_all= defaultdict(lambda :list())
cols=[ 'valence', 'pop_i','fam_i','listening_count']
cols =['danceability', 'energy', 'key', 'loudness',
       'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'duration_ms', 'time_signature']
for label,tracks in gems_groups:
    #print([len(tracks),tracks['lfm_id'].nunique(),(tracks['score']>0).sum()])
    corr_all['label'].append(label)
    for col in cols:
        corr_val,pval = spearmanr(tracks[['score',col]])
        corr_all[f'{col}'].append(corr_val)

# %%
from collections import defaultdict
corr_all= defaultdict(lambda :list())

cols_e =merged_data.columns[-9:]
cols_p =['pop_i','fam_i']
for e in cols_e:
    corr_all['label'].append(e)
    for p in cols_p:
        corr_val,pval = pointbiserialr(merged_data[p],merged_data[e].notna())
        corr_all[f'{p}'].append(corr_val)

# %%
corr_df= pd.DataFrame(corr_all)
corr_df.set_index('label',inplace=True)
sns.heatmap(corr_df, annot=True,cmap='Blues')
# Out:
# <AxesSubplot:ylabel='label'>

# %% [markdown]
# # Calculating correlations on EMMA tracks

# %%
emma_database_merged=pd.read_csv(DATA_ROOT_URL/'v3_emma_database_merge.csv')
itembll_all= pd.read_csv(DATA_ROOT_URL/'bll_scores_global.csv')
merged_data = emma_database_merged.merge(itempop_all,left_on='lfm_id',right_on='track_id',how='inner')
merged_data = merged_data.merge(itemfam_all,left_on='lfm_id',right_on='track_id',how='inner',suffixes=["","_3"])
merged_data = merged_data.merge(itembll_all,left_on='lfm_id',right_on='track_id',how='left',suffixes=["","_3"])
merged_data.loc[merged_data['bll_score'].isna(),'bll_score']=0.0
corr,pval = spearmanr(merged_data[['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness',
       'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness', 'Sublimity',
       'Vitality', 'Unease', 'ICC', 'Familiarity', 'Liking','pop_i','fam_i','bll_score']])

# %%
plt.figure(figsize=(15,15),dpi=200)
plt.title(f"Matching tracks Music4All-Emma :{len(merged_data)}")
sns.heatmap(merged_data[['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness',
       'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness', 'Sublimity',
       'Vitality', 'Unease', 'ICC', 'Familiarity', 'Liking','pop_i','fam_i','bll_score']].corr(),annot=True,cmap='Blues')
# Out:
# <Axes: title={'center': 'Matching tracks Music4All-Emma :43'}>

# %%
merged_data['track_playcount'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
merged_data.drop_duplicates('lfm_id')['track_playcount'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
emma_database_merged = pd.read_csv(DATA_ROOT_URL / "v3_emma_database_merge.csv").iloc[:,:27]
full_feat_tracks = pd.read_csv(
    DATA_ROOT_URL / "v3_emotions_familiarity_full_feat_stack.tsv", sep="\t"
)
itembll_all = pd.read_csv(DATA_ROOT_URL / "bll_scores_1mo.csv")
merged_data = full_feat_tracks.join(
    emma_database_merged, on="lfm_id", how="inner", rsuffix="_emma"
)
itempop_all= pd.read_csv(DATA_ROOT_URL/'track_all_popularity.csv')
itemfam_all= pd.read_csv(DATA_ROOT_URL/'track_all_familiarity.csv')
merged_data = merged_data.merge(itemfam_all,left_on='lfm_id',right_on='track_id',how='left',suffixes=["","_3"])
merged_data = merged_data.merge(itempop_all,left_on='lfm_id',right_on='track_id',how='inner',suffixes=["","_3"])
merged_data = merged_data.merge(itembll_all,left_on='lfm_id',right_on='track_id',how='left',suffixes=["","_3"])
merged_data.loc[merged_data['bll_score'].isna(),'bll_score']=0.0
merged_data.loc[merged_data['fam_i'].isna(),'fam_i']=0.0
merged_data.columns

gems_groups = merged_data.groupby("gem_label")
from collections import defaultdict

corr_all = defaultdict(lambda: list())
cols = [
    "Joy",
    "Nostalgia",
    "Peacfulness",
    "Power",
    "Sadness",
    "Tenderness",
    "Tension",
    "Transcendence",
    "Wonder",
    "Familiarity",
]
for label, tracks in gems_groups:
    
    # print([len(tracks),tracks['lfm_id'].nunique(),(tracks['score']>0).sum()])
    corr_all["label"].append(label)
    for col in cols:
        print(tracks[["score", col]])
        corr_val, pval = spearmanr(tracks[["score", col]])
        corr_all[f"{col}"].append(corr_val)


corr_all["label"].append(f'BLL_1mo')
for col in cols:
    corr_val, pval = spearmanr(merged_data[["bll_score", col]])
    corr_all[f"{col}"].append(corr_val)
corr_all["label"].append(f'fam_i')
for col in cols:
    corr_val, pval = spearmanr(merged_data[["fam_i", col]])
    corr_all[f"{col}"].append(corr_val)    
corr_all["label"].append(f'pop_i')
for col in cols:
    corr_val, pval = spearmanr(merged_data[["pop_i", col]])
    corr_all[f"{col}"].append(corr_val) 
gems_groups["lfm_id"].count()
corr_df = pd.DataFrame(corr_all)
corr_df.set_index("label", inplace=True)
corr_df.index.name = "LFM-user-tags"
corr_df.columns.name = "EMMA Database"
plt.figure(figsize=(12, 20),dpi=200)

sns.heatmap(corr_df, cmap="Blues", annot=True)
plt.title(f'Total tracks:{merged_data["lfm_id"].nunique()}')
# Out:
#           score    Joy
# 19     1.000000  31.21
# 27     8.000000  16.82
# 31    70.000000  35.35
# 47    22.200000  33.57
# 83     3.000000  21.35
# 145   23.666667  31.77
# 179    3.000000  38.62
# 226   28.500000   8.35
# 258   10.000000  32.85
# 271    5.000000  26.35
# 275   25.000000  27.21
# 283    2.000000  21.77
# 287   34.000000  34.20
# 308    4.000000  11.01
# 339  100.000000   9.77
#           score  Nostalgia
# 19     1.000000      17.54
# 27     8.000000       6.76
# 31    70.000000       9.81
# 47    22.200000      12.66
# 83     3.000000      12.42
# 145   23.666667      21.86
# 179    3.000000      11.71
# 226   28.500000      14.90
# 258   10.000000      27.54
# 271    5.000000       8.75
# 275   25.000000       5.05
# 283    2.000000      20.63
# 287   34.000000      12.38
# 308    4.000000      25.95
# 339  100.000000      20.14
#           score  Peacfulness
# 19     1.000000        10.52
# 27     8.000000         8.67
# 31    70.000000        10.30
# 47    22.200000         4.45
# 83     3.000000        13.96
# 145   23.666667         8.39
# 179    3.000000        12.31
# 226   28.500000        22.78
# 258   10.000000        13.58
# 271    5.000000         6.74
# 275   25.000000        12.12
# 283    2.000000        16.35
# 287   34.000000        16.05
# 308    4.000000        26.23
# 339  100.000000        15.92
#           score  Power
# 19     1.000000  24.18
# 27     8.000000   3.95
# 31    70.000000  16.79
# 47    22.200000  20.87
# 83     3.000000   9.06
# 145   23.666667  16.17
# 179    3.000000  14.54
# 226   28.500000   5.20
# 258   10.000000   5.92
# 271    5.000000  17.14
# 275   25.000000  11.66
# 283    2.000000   8.43
# 287   34.000000  23.28
# 308    4.000000   2.12
# 339  100.000000   3.24
#           score  Sadness
# 19     1.000000     3.70
# 27     8.000000     5.16
# 31    70.000000     0.00
# 47    22.200000     0.00
# 83     3.000000     0.00
# 145   23.666667     6.09
# 179    3.000000     2.21
# 226   28.500000     1.17
# 258   10.000000     2.93
# 271    5.000000     1.31
# 275   25.000000     0.00
# 283    2.000000     0.99
# 287   34.000000     0.00
# 308    4.000000     5.92
# 339  100.000000     9.36
#           score  Tenderness
# 19     1.000000        7.78
# 27     8.000000        7.10
# 368  0.500000     0.22
# 377  0.250000    29.94
#         score  Tenderness
# 4    1.000000        6.10
# 49   0.500000        4.90
# 60   1.000000        1.23
# 89   0.312500        1.79
# 148  0.250000       21.23
# 160  0.166667       14.82
# 172  0.500000        5.36
# 180  0.193548       10.57
# 193  0.140351       17.14
# 241  0.166667       13.86
# 276  0.428571        5.98
# 288  0.410714       18.72
# 316  0.451220       22.89
# 357  0.117647        1.96
# 368  0.500000        6.94
# 377  0.250000        9.22
#         score  Tension
# 4    1.000000    17.40
# 49   0.500000     3.60
# 60   1.000000     6.83
# 89   0.312500     6.95
# 148  0.250000     2.26
# 160  0.166667     2.07
# 172  0.500000     1.20
# 180  0.193548     4.36
# 193  0.140351     1.95
# 241  0.166667     4.32
# 276  0.428571     1.83
# 288  0.410714     4.70
# 316  0.451220     0.48
# 357  0.117647     5.76
# 368  0.500000     7.27
# 377  0.250000     4.10
#         score  Transcendence
# 4    1.000000          14.83
# 49   0.500000           6.02
# 60   1.000000           3.35
# 89   0.312500           8.60
# 148  0.250000          12.49
# 160  0.166667           5.08
# 172  0.500000           5.46
# 180  0.193548           5.62
# 193  0.140351          15.30
# 241  0.166667           4.30
# 276  0.428571           5.13
# 288  0.410714          11.51
# 316  0.451220           4.84
# 357  0.117647           4.14
# 368  0.500000           5.80
# 377  0.250000           9.08
#         score  Wonder
# 4    1.000000   18.78
# 49   0.500000    4.90
# 60   1.000000   14.37
# 89   0.312500    8.89
# 148  0.250000   14.64
# 160  0.166667   14.66
# 172  0.500000   28.37
# 180  0.193548   14.22
# 193  0.140351   12.11
# 241  0.166667   26.49
# 276  0.428571   18.88
# 288  0.410714    6.26
# 316  0.451220   15.43
# 357  0.117647    2.78
# 368  0.500000   19.07
# 377  0.250000   15.38
#         score  Familiarity
# 4    1.000000         3.33
# 49   0.500000         1.96
# 60   1.000000         3.30
# 89   0.312500         4.06
# 148  0.250000         3.52
# 160  0.166667         3.19
# 172  0.500000         3.07
# 180  0.193548         3.71
# 193  0.140351         4.12
# 241  0.166667         3.72
# 276  0.428571         4.28
# 288  0.410714         3.31
# 316  0.451220         4.37
# 357  0.117647         2.61
# 368  0.500000         2.94
# 377  0.250000         4.58
#         score    Joy
# 9    0.285714  31.21
# 20   0.500000  16.82
# 32   1.000000  31.78
# 37   0.033898  33.57
# 113  0.333333  23.90
# 125  0.500000  25.86
# 161  0.500000  21.40
# 194  0.122807  30.05
# 242  0.416667  32.85
# 261  0.639640  26.35
# 289  0.142857  11.01
# 317  0.109756  24.23
# 341  0.250000  23.53
# 358  0.235294  21.69
# 392  0.772727  47.74
# 405  0.500000  16.12
#         score  Nostalgia
# 9    0.285714      17.54
# 20   0.500000       6.76
# 32   1.000000       3.08
# 37   0.033898      12.66
# 113  0.333333      15.30
# 125  0.500000      25.84
# 161  0.500000      21.65
# 194  0.122807      19.21
# 242  0.416667      27.54
# 261  0.639640       8.75
# 289  0.142857      25.95
# 317  0.109756      28.53
# 341  0.250000       8.82
# 358  0.235294       6.44
# 392  0.772727       7.10
# 405  0.500000      13.75
#         score  Peacfulness
# 9    0.285714        10.52
# 20   0.500000         8.67
# 32   1.000000         6.88
# 37   0.033898         4.45
# 113  0.333333        14.59
# 125  0.500000        26.65
# 161  0.500000         6.64
# 194  0.122807        17.54
# 242  0.416667        13.58
# 261  0.639640         6.74
# 289  0.142857        26.23
# 317  0.109756        19.85
# 341  0.250000        15.61
# 358  0.235294         6.32
# 392  0.772727        17.02
# 405  0.500000        30.12
#         score  Power
# 9    0.285714  24.18
# 20   0.500000   3.95
# 32   1.000000  22.06
# 37   0.033898  20.87
# 113  0.333333  11.58
# 125  0.500000  15.10
# 161  0.500000   4.42
# 194  0.122807  24.00
# 242  0.416667   5.92
# 261  0.639640  17.14
# 289  0.142857   2.12
# 317  0.109756   7.78
# 341  0.250000  11.81
# 358  0.235294  13.90
# 392  0.772727  32.13
# 405  0.500000   4.26
#         score  Sadness
# 9    0.285714     3.70
# 20   0.500000     5.16
# 32   1.000000     0.44
# 37   0.033898     0.00
# 113  0.333333     0.00
# 125  0.500000     0.00
# 161  0.500000     1.48
# 194  0.122807     0.39
# 242  0.416667     2.93
# 261  0.639640     1.31
# 289  0.142857     5.92
# 317  0.109756     5.44
# 341  0.250000     1.73
# 358  0.235294     0.00
# 392  0.772727     0.00
# 405  0.500000     3.42
#         score  Tenderness
# 9    0.285714        7.78
# 20   0.500000        7.10
# 32   1.000000        0.16
# 37   0.033898       15.27
# 113  0.333333        7.54
# 125  0.500000       19.06
# 161  0.500000       14.82
# 194  0.122807       17.14
# 242  0.416667       13.86
# 261  0.639640        7.76
# 289  0.142857       18.72
# 317  0.109756       22.89
# 341  0.250000       22.38
# 358  0.235294        1.96
# 392  0.772727        1.68
# 405  0.500000       17.13
#         score  Tension
# 9    0.285714    10.22
# 20   0.500000    14.91
# 32   1.000000    17.61
# 37   0.033898     3.15
# 113  0.333333     4.52
# 125  0.500000     0.87
# 161  0.500000     2.07
# 194  0.122807     1.95
# 242  0.416667     4.32
# 261  0.639640     3.03
# 289  0.142857     4.70
# 317  0.109756     0.48
# 341  0.250000     7.87
# 358  0.235294     5.76
# 392  0.772727     6.57
# 405  0.500000     9.06
#         score  Transcendence
# 9    0.285714          10.07
# 20   0.500000           1.64
# 32   1.000000           9.10
# 37   0.033898           1.94
# 113  0.333333          10.71
# 125  0.500000          13.15
# 161  0.500000           5.08
# 194  0.122807          15.30
# 242  0.416667           4.30
# 261  0.639640          11.55
# 289  0.142857          11.51
# 317  0.109756           4.84
# 341  0.250000           5.89
# 358  0.235294           4.14
# 392  0.772727           5.93
# 405  0.500000           9.07
#         score  Wonder
# 9    0.285714   17.40
# 20   0.500000    8.32
# 32   1.000000    6.12
# 37   0.033898    7.23
# 113  0.333333   17.52
# 125  0.500000   23.58
# 161  0.500000   14.66
# 194  0.122807   12.11
# 242  0.416667   26.49
# 261  0.639640   12.32
# 289  0.142857    6.26
# 317  0.109756   15.43
# 341  0.250000   15.43
# 358  0.235294    2.78
# 392  0.772727   19.70
# 405  0.500000   14.44
#         score  Familiarity
# 9    0.285714         4.04
# 20   0.500000         1.84
# 32   1.000000         1.83
# 37   0.033898         3.88
# 113  0.333333         2.31
# 125  0.500000         4.27
# 161  0.500000         3.19
# 194  0.122807         4.12
# 242  0.416667         3.72
# 261  0.639640         3.91
# 289  0.142857         3.31
# 317  0.109756         4.37
# 341  0.250000         3.10
# 358  0.235294         2.61
# 392  0.772727         4.29
# 405  0.500000         1.28
# Text(0.5, 1.0, 'Total tracks:42')

# %%
[
corr_df.iloc[:9,:9].values.diagonal().sum(),
corr_df.iloc[9:18,:9].values.diagonal().sum(),
corr_df.iloc[18:27,:9].values.diagonal().sum(),
corr_df.iloc[27:36,:9].values.diagonal().sum()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/gustavo/gitlab/emotion_listening/notebooks/calculation_emotion_all_aggr.ipynb Cell 56 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/gustavo/gitlab/emotion_listening/notebooks/calculation_emotion_all_aggr.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> [corr_df.iloc[:9,:9].values.diagonal().sum().abs(),
#       <a href='vscode-notebook-cell:/home/gustavo/gitlab/emotion_listening/notebooks/calculation_emotion_all_aggr.ipynb#Y106sZmlsZQ%3D%3D?line=1'>2</a> corr_df.iloc[9:18,:9].values.diagonal().sum().abs(),
#       <a href='vscode-notebook-cell:/home/gustavo/gitlab/emotion_listening/notebooks/calculation_emotion_all_aggr.ipynb#Y106sZmlsZQ%3D%3D?line=2'>3</a> corr_df.iloc[18:27,:9].values.diagonal().sum().abs(),
#       <a href='vscode-notebook-cell:/home/gustavo/gitlab/emotion_listening/notebooks/calculation_emotion_all_aggr.ipynb#Y106sZmlsZQ%3D%3D?line=3'>4</a> corr_df.iloc[27:36,:9].values.diagonal().sum().abs()]
#
# AttributeError: 'numpy.float64' object has no attribute 'abs'

# %%
corr_df.iloc[9:18,:9]
# Out:
# EMMA Database              Joy  Nostalgia  Peacfulness     Power   Sadness  \
# LFM-user-tags
# nr_joyful activation  0.209303  -0.135957    -0.230770  0.203936 -0.344309
# nr_nostalgia          0.507882  -0.395797    -0.308232  0.325745 -0.385965
# nr_peacefulness       0.117156  -0.008368    -0.025105  0.016737 -0.410045
# nr_power              0.199720  -0.414344    -0.314484  0.017885 -0.085574
# nr_sadness            0.292688  -0.237809    -0.054879  0.103660  0.000000
# nr_tenderness         0.737865   0.316228    -0.316228  0.737865 -0.737865
# nr_tension           -0.550782   0.086966     0.289886 -0.086966  0.231908
# nr_transcendence      0.013304   0.209907     0.137474  0.057650  0.521455
# nr_wonder             0.274541  -0.137270    -0.035425  0.057565 -0.005993
#
# EMMA Database         Tenderness   Tension  Transcendence    Wonder
# LFM-user-tags
# nr_joyful activation   -0.062612  0.230770      -0.411450 -0.415027
# nr_nostalgia            0.063047  0.000000      -0.455342 -0.154386
# nr_peacefulness        -0.066946  0.251048      -0.200839  0.117156
# nr_power               -0.274242  0.149045      -0.272953 -0.201210
# nr_sadness              0.274395  0.091465      -0.365860  0.305812
# nr_tenderness           0.632456  0.316228       0.210819  0.948683
# nr_tension              0.347863 -0.985611       0.637748 -0.608760
# nr_transcendence        0.271992  0.096084       0.218776 -0.072433
# nr_wonder              -0.178599 -0.008856       0.073801  0.161005

# %%
full_feat_tracksv2=pd.read_csv(DATA_ROOT_URL/'v2_emotions_familiarity_full_feat_stack.tsv',sep='\t')
full_feat_tracksv1=pd.read_csv(DATA_ROOT_URL/'emotions_familiarity_full_feat_stack.tsv',sep='\t')

# %%
full_feat_tracksv1.set_index(['id','gem_label'],inplace=True)
full_feat_tracksv2.set_index(['id','gem_label'],inplace=True)

# %%
concatenated =pd.concat([full_feat_tracksv1,full_feat_tracksv2],axis=1,join='inner')#[['id','gem_label_norm','score_norm','gem_label','score']]

# %%
concatenated.columns
# Out:
# Index(['row_id', 'score', '(tag, weight)', 'gems', 'gems_profile', 'genre',
#        'microgenre', 'lfm_id', 'date', 'date_prec', 'year', 'month', 'day',
#        'release_date', 'row_id', 'score', 'track_uri', 'date', 'date_prec',
#        'gems', 'gems_profile', 'gems_profile_no_rescaling', 'genre',
#        'microgenre', 'lfm_id', 'year', 'month', 'day', 'release_date'],
#       dtype='object')

# %%
values=concatenated['score']

# %%
values.columns =['score_norm', 'score']

# %%
values.reset_index().dropna().to_csv(DATA_ROOT_URL/'norm_vs_notnorm_gems.csv',index=False)

# %%
values = pd.read_csv(DATA_ROOT_URL/'norm_vs_notnorm_gems.csv')
# Out:
#                      id          gem_label  score_norm  score  Unnamed: 0  \
# 0      007LIJOPQ4Sb98qV         tenderness    1.000000    7.0         NaN
# 1      00CH4HJdxQQQbJfu      transcendence    1.000000   70.0         NaN
# 2      00P2bHdWFkghmDqz             wonder    0.500000    8.0         NaN
# 3      00P2bHdWFkghmDqz  joyful activation    0.500000    8.0         NaN
# 4      00mLjKFmaTv9MdaB              power    0.025424    3.0         NaN
# ...                 ...                ...         ...    ...         ...
# 40394  zzx8CWdM7qkxKQpC              power    0.233333    7.0         NaN
# 40395  zzx8CWdM7qkxKQpC             wonder    0.366667   11.0         NaN
# 40396  zzx8CWdM7qkxKQpC  joyful activation    0.266667    8.0         NaN
# 40397  zzx8CWdM7qkxKQpC            sadness    0.133333    4.0         NaN
# 40398  zzzwh2ktIWjsR7xp          nostalgia    1.000000   13.0         NaN
#
#       artist title  Wonder  Transcendence  Nostalgia  ...  lfm_id  power  \
# 0        NaN   NaN     NaN            NaN        NaN  ...     NaN    NaN
# 1        NaN   NaN     NaN            NaN        NaN  ...     NaN    NaN
# 2        NaN   NaN     NaN            NaN        NaN  ...     NaN    NaN
# 3        NaN   NaN     NaN            NaN        NaN  ...     NaN    NaN
# 4        NaN   NaN     NaN            NaN        NaN  ...     NaN    NaN
# ...      ...   ...     ...            ...        ...  ...     ...    ...
# 40394    NaN   NaN     NaN            NaN        NaN  ...     NaN    NaN
# 40395    NaN   NaN     NaN            NaN        NaN  ...     NaN    NaN
# 40396    NaN   NaN     NaN            NaN        NaN  ...     NaN    NaN
# 40397    NaN   NaN     NaN            NaN        NaN  ...     NaN    NaN
# 40398    NaN   NaN     NaN            NaN        NaN  ...     NaN    NaN
#
#        tenderness  transcendence  wonder  joyful activation  tension  \
# 0             NaN            NaN     NaN                NaN      NaN
# 1             NaN            NaN     NaN                NaN      NaN
# 2             NaN            NaN     NaN                NaN      NaN
# 3             NaN            NaN     NaN                NaN      NaN
# 4             NaN            NaN     NaN                NaN      NaN
# ...           ...            ...     ...                ...      ...
# 40394         NaN            NaN     NaN                NaN      NaN
# 40395         NaN            NaN     NaN                NaN      NaN
# 40396         NaN            NaN     NaN                NaN      NaN
# 40397         NaN            NaN     NaN                NaN      NaN
# 40398         NaN            NaN     NaN                NaN      NaN
#
#        nostalgia  sadness  peacefulness
# 0            NaN      NaN           NaN
# 1            NaN      NaN           NaN
# 2            NaN      NaN           NaN
# 3            NaN      NaN           NaN
# 4            NaN      NaN           NaN
# ...          ...      ...           ...
# 40394        NaN      NaN           NaN
# 40395        NaN      NaN           NaN
# 40396        NaN      NaN           NaN
# 40397        NaN      NaN           NaN
# 40398        NaN      NaN           NaN
#
# [40399 rows x 43 columns]

# %%
merged  = values.merge(emma_database_merged,left_on='id',right_on='_id',how='inner',suffixes=["","_emma"])

# %%
merged.drop_duplicates(subset=['id','gem_label'])
# Out:
#                   id          gem_label  score_norm  score  Unnamed: 0  \
# 0   6sUE7Mf0a49mHeJr      transcendence    0.888889   16.0           8
# 1   6sUE7Mf0a49mHeJr            sadness    0.111111    2.0           8
# 2   ABwvIfsLLaa97kJp      transcendence    0.500000   31.0          16
# 3   ABwvIfsLLaa97kJp  joyful activation    0.161290   10.0          16
# 4   ABwvIfsLLaa97kJp          nostalgia    0.306452   19.0          16
# ..               ...                ...         ...    ...         ...
# 71  zbI3TrMSY2chqzRz      transcendence    0.633333   38.0          32
# 72  zbI3TrMSY2chqzRz  joyful activation    0.016667    1.0          32
# 73  zbI3TrMSY2chqzRz          nostalgia    0.100000    6.0          32
# 74  zbI3TrMSY2chqzRz            sadness    0.083333    5.0          32
# 75  zbI3TrMSY2chqzRz       peacefulness    0.166667   10.0          32
#
#       artist            title  Wonder  Transcendence  Nostalgia  ...  lfm_id  \
# 0       2Pac  Keep Ya Head Up    4.90           6.02       5.52  ...    2624
# 1       2Pac  Keep Ya Head Up    4.90           6.02       5.52  ...    2624
# 2   Mattafix    Big City Life   17.52          10.71      15.30  ...    3950
# 3   Mattafix    Big City Life   17.52          10.71      15.30  ...    3950
# 4   Mattafix    Big City Life   17.52          10.71      15.30  ...    3950
# ..       ...              ...     ...            ...        ...  ...     ...
# 71      Dido       White Flag    6.26          11.51      25.95  ...   24240
# 72      Dido       White Flag    6.26          11.51      25.95  ...   24240
# 73      Dido       White Flag    6.26          11.51      25.95  ...   24240
# 74      Dido       White Flag    6.26          11.51      25.95  ...   24240
# 75      Dido       White Flag    6.26          11.51      25.95  ...   24240
#
#     power  tenderness  transcendence  wonder  joyful activation  tension  \
# 0     0.0         0.0       0.888889     0.0           0.000000      0.0
# 1     0.0         0.0       0.888889     0.0           0.000000      0.0
# 2     0.0         0.0       0.500000     0.0           0.161290      0.0
# 3     0.0         0.0       0.500000     0.0           0.161290      0.0
# 4     0.0         0.0       0.500000     0.0           0.161290      0.0
# ..    ...         ...            ...     ...                ...      ...
# 71    0.0         0.0       0.633333     0.0           0.016667      0.0
# 72    0.0         0.0       0.633333     0.0           0.016667      0.0
# 73    0.0         0.0       0.633333     0.0           0.016667      0.0
# 74    0.0         0.0       0.633333     0.0           0.016667      0.0
# 75    0.0         0.0       0.633333     0.0           0.016667      0.0
#
#     nostalgia   sadness  peacefulness
# 0    0.000000  0.111111      0.000000
# 1    0.000000  0.111111      0.000000
# 2    0.306452  0.000000      0.032258
# 3    0.306452  0.000000      0.032258
# 4    0.306452  0.000000      0.032258
# ..        ...       ...           ...
# 71   0.100000  0.083333      0.166667
# 72   0.100000  0.083333      0.166667
# 73   0.100000  0.083333      0.166667
# 74   0.100000  0.083333      0.166667
# 75   0.100000  0.083333      0.166667
#
# [76 rows x 43 columns]

# %%
a=sorted( ['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness',
       'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness'])

b=sorted(['power', 'tenderness',
       'transcendence', 'wonder', 'joyful activation', 'tension', 'nostalgia',
       'sadness', 'peacefulness'])
lfm2emma= {k:v for k,v in zip(b,a)}

# %%
merged['emma']=[merged.loc[row[0],lfm2emma.get(row[1]['gem_label'])] for row in  merged.iterrows()]

# %%
merged.columns
# Out:
# Index(['id', 'gem_label', 'score_norm', 'score', 'Unnamed: 0', 'artist',
#        'title', 'Wonder', 'Transcendence', 'Nostalgia', 'Tenderness',
#        'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness', 'Sublimity',
#        'Vitality', 'Unease', 'ICC', 'Familiarity', 'Liking', '_id', 'track',
#        'album', 'lfm', 'spotify', 'id_emma', '(tag, weight)', 'gems',
#        'gems_profile', 'genre', 'microgenre', 'lfm_id', 'power', 'tenderness',
#        'transcendence', 'wonder', 'joyful activation', 'tension', 'nostalgia',
#        'sadness', 'peacefulness', 'emma'],
#       dtype='object')

# %%
merged[['id', 'gem_label', 'score_norm', 'score','emma']].to_csv(DATA_ROOT_URL/'lfm_norm_lfm_emma.csv',index=False)

# %%
merged[['id', 'gem_label', 'score_norm', 'score','emma']]
# Out:
#                      id          gem_label  score_norm  score   emma
# 4521   6sUE7Mf0a49mHeJr      transcendence    0.888889   16.0   6.02
# 4522   6sUE7Mf0a49mHeJr            sadness    0.111111    2.0   3.12
# 6776   ABwvIfsLLaa97kJp      transcendence    0.500000   31.0  10.71
# 6777   ABwvIfsLLaa97kJp  joyful activation    0.161290   10.0  23.90
# 6778   ABwvIfsLLaa97kJp          nostalgia    0.306452   19.0  15.30
# ...                 ...                ...         ...    ...    ...
# 40083  zbI3TrMSY2chqzRz      transcendence    0.633333   38.0  11.51
# 40084  zbI3TrMSY2chqzRz  joyful activation    0.016667    1.0  11.01
# 40085  zbI3TrMSY2chqzRz          nostalgia    0.100000    6.0  25.95
# 40086  zbI3TrMSY2chqzRz            sadness    0.083333    5.0   5.92
# 40087  zbI3TrMSY2chqzRz       peacefulness    0.166667   10.0  26.23
#
# [76 rows x 5 columns]

# %%
full_feat_tracksv2.isna().sum()
# Out:
# row_id                       0
# score                        0
# track_uri                    0
# date                         0
# date_prec                    0
# gems                         0
# gems_profile                 0
# gems_profile_no_rescaling    0
# genre                        0
# microgenre                   0
# lfm_id                       0
# year                         0
# month                        0
# day                          0
# release_date                 0
# dtype: int64

# %%
np.intersect1d(full_feat_tracksv1.index.get_level_values(0).unique(),full_feat_tracksv2.index.get_level_values(0).unique()).shape
# Out:
# (16435,)

# %%
np.

# %% [markdown]
# VAE: can fit sequentiality by buckets
# KNN: pointwise
# GRU4Rec: Seq-RL chose 1 item
